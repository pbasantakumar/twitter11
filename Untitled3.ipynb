# %% [markdown]
# <a href="https://colab.research.google.com/github/pbasantakumar/twitter11/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# from google.colab import files
# uploaded = files.upload()
# coonect as OATH jump server
consumer_key = "UgSlsnLVlvWsAZjebUdzwXlT6"
consumer_sec = "isJC9mfe85shl0Pch6uofjDgGfPeQdTPN8c4KNCWrC0RwNH7jt"

# from proxy server we need to connect
access_token = "470819711-Yo7Nw3Rebmv1MB6n5qMdRTpqPqlz0KCsYVDbZkcQ"
access_token_sec = "m1dBkLTfnNXeNF6onBXhItUep8BIQjxl5Be2OkaEv2Sdu"
# connect to jump server of twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_sec)

# now we can connect from jump server to webserver of twitter
auth.set_access_token(access_token, access_token_sec)

# now we can connect to API strong server of twitter
api_connect = tweepy.API(auth)

posts = api_connect.user_timeline(screen_name="IKEY", count=1000, tweet_mode="extended")
print("show the recent 5 tweets: \n")
i = 1
for tweet in posts[0:100]:
    print(str(i) + ') ' + str(tweet.id)+' ' + str(tweet.created_at) + str(tweet.full_text) + '\n')
    i = i + 1

    # Create a dataframe with a column called Tweets
    
    #df = pd.DataFrame([tweet.id for tweet in posts], columns=['id'])
    #df = pd.DataFrame([tweet.id for tweet in posts], columns=['created_at'])
    df = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
    df.head()
# Out:
# show the recent 5 tweets:
#
# 1) 1496716174012338185 2022-02-24 05:18:38@MichaeleeWenner zero bands. zero bitches.
#
# 2) 1492331111015497731 2022-02-12 02:53:57@MichaeleeWenner @ProtonXPR you aint giving anyone anything for valentine's is you 🧐🧐🧐
#
# 3) 1491468911736410120 2022-02-09 17:47:53@MichaeleeWenner @fataleth how about you go NFSEE some bitches
#
# 4) 1490116904530370562 2022-02-06 00:15:29@qualityvelasco im glad you like him! 🐱 https://t.co/OlbCGi4tkW
#
# 5) 1490048233401458710 2022-02-05 19:42:37@wrongvelasco @qualityvelasco his name is howard https://t.co/4LeiQM30VL
#
# 6) 1489362080771805186 2022-02-03 22:16:05cry//pto mfs are annoying as fuck
#
# 7) 1482298521797681154 2022-01-15 10:28:02https://t.co/eisAvxNYJN
#
# 8) 1471277405658562560 2021-12-16 00:34:03https://t.co/SnPbusQfrs
#
# 9) 1465159591784763392 2021-11-29 03:24:02the virgil news still has me fucked up man
#
# 10) 1462920138014052359 2021-11-22 23:05:15https://t.co/Ff58lBRqCg
#
# 11) 1462919774808285186 2021-11-22 23:03:48@Vincimadu4 @judenaks @judekuch succor coin? more like succon my cock
#
# 12) 1437925268870549516 2021-09-14 23:44:34https://t.co/LpWZJIZwLq
#
# 13) 1435706751509217281 2021-09-08 20:48:58i miss this bastard https://t.co/fvVrcDmaFz
#
# 14) 1408304416483074051 2021-06-25 06:01:52new tyler slaps, finna bump this for weeks ong
#
# 15) 1405062738003566594 2021-06-16 07:20:36crazy eyes https://t.co/HvZrwMmqw7
#
# 16) 1388137581481799687 2021-04-30 14:26:04@snakiness m750 tkl
#
# 17) 1387878499889958915 2021-04-29 21:16:34https://t.co/yGaL2SdeoQ
#
# 18) 1384623171450679303 2021-04-20 21:41:03suck a massive dick you loser #ripbozo
#
# it's a start, but now more needs to be done. also, be careful tonight everyone.
#
# 56) 1346091401000456193 2021-01-04 13:49:33f*ck
#
# 57) 1315989171585134593 2020-10-13 12:14:03stunning out this morning https://t.co/gRWa3WzC8i
#
# 58) 1311167679324196864 2020-09-30 04:55:09late nights https://t.co/TFcxYsC0q8
#
# 59) 1264418881264922624 2020-05-24 04:52:07✨ https://t.co/JQqzgu6CN1
#
# 60) 1258563825512730624 2020-05-08 01:06:13chilly https://t.co/wN9u9nVCeH
#
# 61) 1254013295935328256 2020-04-25 11:44:02he's judging you https://t.co/t3hkD612zp
#
# 62) 1252803739834032128 2020-04-22 03:37:42hmm https://t.co/v6S68fcArX
#
# 63) 1244466202140868608 2020-03-30 03:27:18https://t.co/aPHAJCog5R

# %%
#Create a function to get the subjectivity
i=1
for tweet in posts[0:5]:
  df['ID'] = str(tweet.id)
  df['created_at'] = str(tweet.created_at)
  df['Tweets'] = df['Tweets']
  i = i + 1
df
# Out:
#                                                Tweets                   ID  \
# 0          @MichaeleeWenner zero bands. zero bitches.  1490048233401458710
# 1   @MichaeleeWenner @ProtonXPR you aint giving an...  1490048233401458710
# 2   @MichaeleeWenner @fataleth how about you go NF...  1490048233401458710
# 3   @qualityvelasco im glad you like him! 🐱 https:...  1490048233401458710
# 4   @wrongvelasco @qualityvelasco his name is howa...  1490048233401458710
# ..                                                ...                  ...
# 58                          ✨ https://t.co/JQqzgu6CN1  1490048233401458710
# 59                     chilly https://t.co/wN9u9nVCeH  1490048233401458710
# 60           he's judging you https://t.co/t3hkD612zp  1490048233401458710
# 61                        hmm https://t.co/v6S68fcArX  1490048233401458710
# 62                            https://t.co/aPHAJCog5R  1490048233401458710
#
#              created_at
# 0   2022-02-05 19:42:37
# 1   2022-02-05 19:42:37
# 2   2022-02-05 19:42:37
# 3   2022-02-05 19:42:37
# 4   2022-02-05 19:42:37
# ..                  ...
# 58  2022-02-05 19:42:37
# 59  2022-02-05 19:42:37
# 60  2022-02-05 19:42:37
# 61  2022-02-05 19:42:37
# 62  2022-02-05 19:42:37
#
# [63 rows x 3 columns]

# %% [markdown]
# # New Section

# %%
# Clean the text function
def cleanTxt(text):
        #print("Inside cleantext: \n")
        text = re.sub(r'@[A-Za-z0-9]+', '', text)  # Remove @mentioned
        text = re.sub(r'#', '', text)  # Remove the # symbol
        text = re.sub(r'_', '', text)  # Remove the _ symbol
        text = re.sub(r'RT[\s]+', '', text)  # Remove RT
        text = re.sub(r'https?:\/\/\s+', '', text)  # Removing hyperlink
        text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
        text = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', text, flags=re.MULTILINE)
        text = re.sub(r'http[s]?://\S+', '', text) 
        text = re.sub(r'http://\S+|https://\S+', '', text)
        return text
    #cleaning the text
df['Tweets'] = df['Tweets'].apply(cleanTxt)

    # show the clean text
df
# Out:
#                                                Tweets                   ID  \
# 0                           zero bands. zero bitches.  1490048233401458710
# 1     you aint giving anyone anything for valentin...  1490048233401458710
# 2                 how about you go NFSEE some bitches  1490048233401458710
# 3                            im glad you like him! 🐱   1490048233401458710
# 4                                 his name is howard   1490048233401458710
# ..                                                ...                  ...
# 58                                                 ✨   1490048233401458710
# 59                                            chilly   1490048233401458710
# 60                                  he's judging you   1490048233401458710
# 61                                               hmm   1490048233401458710
# 62                                                     1490048233401458710
#
#              created_at
# 0   2022-02-05 19:42:37
# 1   2022-02-05 19:42:37
# 2   2022-02-05 19:42:37
# 3   2022-02-05 19:42:37
# 4   2022-02-05 19:42:37
# ..                  ...
# 58  2022-02-05 19:42:37
# 59  2022-02-05 19:42:37
# 60  2022-02-05 19:42:37
# 61  2022-02-05 19:42:37
# 62  2022-02-05 19:42:37
#
# [63 rows x 3 columns]

# %%
#Create a function to get the subjectivity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity
  print("Inside cleantext1: \n")

#Create a function to get the polarity
def getPolarity(text):
  return TextBlob(text).sentiment.polarity
print("Inside cleantext1: \n")

#Create two new columns
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] =df['Tweets'].apply(getPolarity)
df
# Out:
# Inside cleantext1:
#                                                Tweets                   ID  \
# 0                           zero bands. zero bitches.  1490048233401458710
# 1     you aint giving anyone anything for valentin...  1490048233401458710
# 2                 how about you go NFSEE some bitches  1490048233401458710
# 3                            im glad you like him! 🐱   1490048233401458710
# 4                                 his name is howard   1490048233401458710
# ..                                                ...                  ...
# 58                                                 ✨   1490048233401458710
# 59                                            chilly   1490048233401458710
# 60                                  he's judging you   1490048233401458710
# 61                                               hmm   1490048233401458710
# 62                                                     1490048233401458710
#
#              created_at  Subjectivity  Polarity
# 0   2022-02-05 19:42:37           0.0     0.000
# 1   2022-02-05 19:42:37           0.0     0.000
# 2   2022-02-05 19:42:37           0.0     0.000
# 3   2022-02-05 19:42:37           1.0     0.625
# 4   2022-02-05 19:42:37           0.0     0.000
# ..                  ...           ...       ...
# 58  2022-02-05 19:42:37           0.0     0.000
# 59  2022-02-05 19:42:37           0.9    -0.600
# 60  2022-02-05 19:42:37           0.0     0.000
# 61  2022-02-05 19:42:37           0.0     0.000
# 62  2022-02-05 19:42:37           0.0     0.000
#
# [63 rows x 5 columns]

# %%
# Plot The Word Cloud
allWords = ' '.join([twts for twts in df['Tweets']])
wordCloud = WordCloud(width = 500, height= 300, random_state = 21, max_font_size = 119).generate(allWords)
plt.imshow(wordCloud,interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
#Create a function to compute the negative , neutral and positive analysis
def getAnalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
      return 'Neutral'
  else:
      return 'Positive'

df['Analysis']= df['Polarity'].apply(getAnalysis)
df
# Out:
#                                                Tweets                   ID  \
# 0                           zero bands. zero bitches.  1490048233401458710
# 1     you aint giving anyone anything for valentin...  1490048233401458710
# 2                 how about you go NFSEE some bitches  1490048233401458710
# 3                            im glad you like him! 🐱   1490048233401458710
# 4                                 his name is howard   1490048233401458710
# ..                                                ...                  ...
# 58                                                 ✨   1490048233401458710
# 59                                            chilly   1490048233401458710
# 60                                  he's judging you   1490048233401458710
# 61                                               hmm   1490048233401458710
# 62                                                     1490048233401458710
#
#              created_at  Subjectivity  Polarity  Analysis
# 0   2022-02-05 19:42:37           0.0     0.000   Neutral
# 1   2022-02-05 19:42:37           0.0     0.000   Neutral
# 2   2022-02-05 19:42:37           0.0     0.000   Neutral
# 3   2022-02-05 19:42:37           1.0     0.625  Positive
# 4   2022-02-05 19:42:37           0.0     0.000   Neutral
# ..                  ...           ...       ...       ...
# 58  2022-02-05 19:42:37           0.0     0.000   Neutral
# 59  2022-02-05 19:42:37           0.9    -0.600  Negative
# 60  2022-02-05 19:42:37           0.0     0.000   Neutral
# 61  2022-02-05 19:42:37           0.0     0.000   Neutral
# 62  2022-02-05 19:42:37           0.0     0.000   Neutral
#
# [63 rows x 6 columns]

# %%
#Print all of the positive tweets
j=1
sortedDF = df.sort_values(by=['Polarity'])
for i in range(0, sortedDF.shape[0]):
  if (sortedDF['Analysis'][i] == 'Positive'):
    print(str(j)+')'+sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# 1) im glad you like him! 🐱
#
# 2)   succor coin? more like succon my cock
#
# 3)new tyler slaps, finna bump this for weeks ong
#
# 4)suck a massive dick you loser ripbozo
#
# it's a start, but now more needs to be done. also, be careful tonight everyone.
#
# 5)looking very polite
#
# 6) bro 💀💀
#
# i literally only post wacky shit on here lmaooo
#
# 7)remember to tell your friends you love them, because at some point you're not gonna be able to do it again
#
# 8)i might be too far gone to listen
#
# 9)40 thats how many
#
# 10)how many tweets
#
# 11)stunning out this morning

# %%
#Print all of the Negative tweets
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending = 'False')
for i in range(0, sortedDF.shape[0]):
  if (sortedDF['Analysis'][i] == 'Negative'):
    print(str(j)+')'+sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# 1)cry//pto mfs are annoying as fuck
#
# 2)the virgil news still has me fucked up man
#
# 3)crazy eyes
#
# 4)It was dark last night
#
# 5)I can't believe I was born ...... so crazy
#
# 6)all this swag and still lonely asf 😔😔😔
#
# 7)wait I'm sorry, b*tch
#
# 8)sometimes i wonder what would happen if i started replying to the random people that accidentally mention me
#
# 9)cold as hell
#
# 10)late nights
#
# 11)chilly

# %%
#Print all of the tweets created at 
j=1
sortedDF = df.sort_values(by=['created_at'])
for i in range(0, sortedDF.shape[0]):
  if (sortedDF['created_at'][i] == 'created_at'):
    print(str(j)+')'+sortedDF['Tweets'][i])
    print()
    j=j+1

# %%
#plot the polarity and sujectvity
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
  plt.scatter(df['Polarity'][i],df['Subjectivity'][i],color='Blue')
  plt.title('Sentiment Analysis')
  plt.xlabel('Polarity')
  plt.ylabel('Suubjectivity')
  plt.show

# %%
#Get the Percentage of positive Tweets
ptweets = df[df.Analysis== 'Positive']
ptweets = ptweets['Tweets']
round( (ptweets.shape[0] / df.shape[0])*100,1)
# Out:
# 29.3

# %%
#Get the percentage of Negative Tweets
ntweets = df[df.Analysis =='Negative']
ntweets = ntweets['Tweets']
round( (ntweets.shape[0] / df.shape[0])*100,1)
# Out:
# 14.6

# %%
#Show the value counts
df['Analysis'].value_counts()
#plot and cisualize the counts
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind='bar')

# %%
#Show the value counts
df['Analysis'].value_counts()

#plot and cisualize the counts
plt.title('Sentiment Analysis by time')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['created_at'].value_counts().plot(kind='bar')
